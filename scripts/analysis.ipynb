# %%
import pandas as pd

# %%
df = pd.read_csv('../data/processed/processed_sentiment_analysis.csv')

# %%
df.columns
# Out:
# Index(['subreddit', 'post_id', 'post_created_utc', 'post_title', 'post_body',
#        'post_score', 'post_url', 'comment_id', 'comment_body', 'comment_score',
#        'comment_created_utc', 'post_text_raw', 'comment_text_raw', 'text_raw',
#        'post_text_clean', 'comment_text_clean', 'text_clean', 'post_text_lem',
#        'comment_text_lem', 'text_lem', 'topic_id', 'topic_strength',
#        'comment_subtopic', 'sentiment_text', 'vader_compound', 'vader_pos',
#        'vader_neu', 'vader_neg', 'vader_label', 'bert_label', 'bert_score'],
#       dtype='object')

# %%
df.sample(1)
# Out:
#             subreddit  post_id  post_created_utc  \
# 130182  Perimenopause  1ljpg1b      1.750805e+09
#
#                                                post_title  \
# 130182  When did you realize when you’re finally In pe...
#
#                                                 post_body  post_score  \
# 130182  When I stared at my front door keypad with no ...         120
#
#                                                  post_url comment_id  \
# 130182  /r/Perimenopause/comments/1ljpg1b/when_did_you...    n006k0g
#
#                                              comment_body  comment_score  ...  \
# 130182  SAME. Every 28-29 days now. Started about a ye...              3  ...
#
#         topic_strength comment_subtopic  \
# 130182        0.529349                1
#
#                                            sentiment_text vader_compound  \
# 130182  SAME. Every 28 29 days now. Started about a ye...        -0.3612
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167150 entries, 0 to 167149
# Data columns (total 31 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   subreddit            167150 non-null  object
#  1   post_id              167150 non-null  object
#  2   post_created_utc     167150 non-null  float64
#  3   post_title           167150 non-null  object
#  4   post_body            158235 non-null  object
#  5   post_score           167150 non-null  int64
#  6   post_url             167150 non-null  object
#  7   comment_id           167150 non-null  object
#  8   comment_body         167150 non-null  object
#  9   comment_score        167150 non-null  int64
#  10  comment_created_utc  167150 non-null  float64
#  11  post_text_raw        167150 non-null  object
#  12  comment_text_raw     167150 non-null  object
#  13  text_raw             167150 non-null  object
#  14  post_text_clean      167150 non-null  object
# ...

# %%
df['post_id'].nunique()
# Out:
# 1559

# %%
df['comment_id'].nunique()
# Out:
# 167150
